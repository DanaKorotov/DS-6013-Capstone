# %%
# !pip install geopandas
# !pip install Shapely

# %%
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd 
import matplotlib.pyplot as plt
from geopandas import GeoDataFrame

# %%
df = pd.read_csv("/Users/stephenkullman/Desktop/School of Data Science/Capstone/ee-live.csv")

# %%
df.head()
# Out:
#          FID       mmsi  source_id        imo   vessel_name callsign  \
# 0  512001064  512001064        153        NaN   UNAVAILABLE   ZM5505
# 1  512008000  512008000        153  9057111.0  SAN AOTEA II   ZM2534
# 2  499054494  499054494         66        NaN   UNAVAILABLE      NaN
# 3  367539910  367539910        153        NaN   UNAVAILABLE  WDG4768
# 4  512002048  512002048        153        NaN   UNAVAILABLE   ZM2117
#
#       vessel_type  vessel_type_code vessel_type_cargo vessel_class  ...  \
# 0         Fishing              30.0               NaN            B  ...
# 1         Fishing              30.0               NaN            A  ...
# 2     UNAVAILABLE               NaN               NaN          NaN  ...
# 3  Pleasure Craft              37.0               NaN            A  ...
# 4         Sailing              36.0               NaN          NaN  ...
#
#     ts_static_utc   ts_insert_utc           dt_pos_utc        dt_static_utc  \
# ...

# %%
geometry = [Point(xy) for xy in zip(df.longitude, df.latitude)]
gdf = GeoDataFrame(df,geometry=geometry)
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(15,15)),marker='o',color="red", markersize=5)
# Out:
# /var/folders/l9/qjwh76rx6wjbn8s0p0_2hd9w0000gp/T/ipykernel_51138/3774818409.py:3: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <Axes: >

# %%
df.head()
# Out:
#          FID       mmsi  source_id        imo   vessel_name callsign  \
# 0  512001064  512001064        153        NaN   UNAVAILABLE   ZM5505
# 1  512008000  512008000        153  9057111.0  SAN AOTEA II   ZM2534
# 2  499054494  499054494         66        NaN   UNAVAILABLE      NaN
# 3  367539910  367539910        153        NaN   UNAVAILABLE  WDG4768
# 4  512002048  512002048        153        NaN   UNAVAILABLE   ZM2117
#
#       vessel_type  vessel_type_code vessel_type_cargo vessel_class  ...  \
# 0         Fishing              30.0               NaN            B  ...
# 1         Fishing              30.0               NaN            A  ...
# 2     UNAVAILABLE               NaN               NaN          NaN  ...
# 3  Pleasure Craft              37.0               NaN            A  ...
# 4         Sailing              36.0               NaN          NaN  ...
#
#     ts_static_utc   ts_insert_utc           dt_pos_utc        dt_static_utc  \
# ...

# %%
df.mmsi.value_counts().sort_values(ascending=False)
# Out:
# 412000009    2
# 123456789    2
# 211336340    1
# 994162690    1
# 273843810    1
#             ..
# 352001828    1
# 273616820    1
# 273395730    1
# 319146400    1
# 416000815    1
# Name: mmsi, Length: 196177, dtype: int64

# %%
test = df.query("mmsi == 412000009")
test
# Out:
#               FID       mmsi  source_id  imo         vessel_name callsign  \
# 7317    412000009  412000009        153  NaN  DONGYU1518-009100%        0
# 132283  412000009  412000009        139  NaN               60059        0
#
#         vessel_type  vessel_type_code vessel_type_cargo vessel_class  ...  \
# 7317    UNAVAILABLE               NaN               NaN            B  ...
# 132283  Port Tender              53.0               NaN            B  ...
#
#          ts_static_utc   ts_insert_utc           dt_pos_utc  \
# 7317    20230925132351  20230925133818  2023-09-25 13:23:51
# 132283  20230925133425  20230925134253  2023-09-25 13:34:25
#
#               dt_static_utc        dt_insert_utc  vessel_type_main  \
# 7317    2023-09-25 13:23:51  2023-09-25 13:38:18               NaN
# 132283  2023-09-25 13:34:25  2023-09-25 13:42:53               NaN
#
#         vessel_type_sub message_type  eeid                  dtg
# ...

# %%
geometry2 = [Point(xy) for xy in zip(test.longitude, test.latitude)]
gdf2 = GeoDataFrame(test,geometry=geometry2)
world2 = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf2.plot(ax=world.plot(figsize=(15,15)),marker='o',color="red", markersize=5)
# Out:
# /var/folders/l9/qjwh76rx6wjbn8s0p0_2hd9w0000gp/T/ipykernel_51138/1725064536.py:3: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world2 = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <Axes: >
